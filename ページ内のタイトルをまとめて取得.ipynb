# %%
from selenium import webdriver
browser = webdriver.Chrome()
browser.get('https://scraping-for-beginner.herokuapp.com/ranking/')

# %%
elem_rankingBox = browser.find_element_by_class_name('u_areaListRankingBox')
elem_title = elem_rankingBox.find_element_by_class_name('u_title')
elem_title.text
# Out:
# /var/folders/00/17_ysw_55nz32_z224xhl0dh0000gn/T/ipykernel_79806/4018317604.py:1: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   elem_rankingBox = browser.find_element_by_class_name('u_areaListRankingBox')
# '1\n観光地 1'

# %%
len(elems_rankingBox)
# Out:
# /var/folders/00/17_ysw_55nz32_z224xhl0dh0000gn/T/ipykernel_79806/3925588177.py:1: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   elems_rankingBox = browser.find_elements_by_class_name('u_areaListRankingBox')
# 10

# %%
elem_rankingBox = browser.find_element_by_class_name('u_areaListRankingBox')
elem_title = elem_rankingBox.find_element_by_class_name('u_title')
elem_title.text
elems_rankingBox = browser.find_elements_by_class_name('u_areaListRankingBox')
# 全ての観光地名を格納するリスト titles
titles = []

for elem_rankingBox in elems_rankingBox:
    #elem_rankingBox = elems_rankingBox[1]
    elem_title = elem_rankingBox.find_element_by_class_name('u_title')
    title = elem_title.text.split('\n')[1]
    titles.append(title)
# Out:
# /var/folders/00/17_ysw_55nz32_z224xhl0dh0000gn/T/ipykernel_79806/2966292970.py:1: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   elems_rankingBox = browser.find_elements_by_class_name('u_areaListRankingBox')

# %%
titles
# Out:
# ['観光地 1',
#  '観光地 2',
#  '観光地 3',
#  '観光地 4',
#  '観光地 5',
#  '観光地 6',
#  '観光地 7',
#  '観光地 8',
#  '観光地 9',
#  '観光地 10']

# %%
elems_rank = elems_rankingBox[0].find_elements_by_class_name('u_categoryTipsItem')[0].find_elements_by_class_name('is_rank')
ranks = []

for elem_rank in elems_rank:
    elem_rank = elems_rank.find_element_by_class_name('evaluateNumber')
    rank = elem_rank.text
    ranks.append(rank)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/00/17_ysw_55nz32_z224xhl0dh0000gn/T/ipykernel_79806/969899939.py in <module>
#       3
#       4 for elem_rank in elems_rank:
# ----> 5     elem_rank = elems_rank.find_element_by_class_name('evaluateNumber')
#       6     rank = elem_rank.text
#       7     ranks.append(rank)
#
# AttributeError: 'list' object has no attribute 'find_element_by_class_name'

# %%
elems_rankingBox[0].find_elements_by_class_name('u_categoryTipsItem')[0].find_elements_by_class_name('is_rank')[1].text
# Out:
# '4.5'
